# %%
import line_profiler
import pandas as pd
import uproot
#import uproot3
import numpy as np
# import track_time_calibration as ttc
from matplotlib import pyplot as plt
import sys
from tqdm import tqdm
sys.path.insert(1, r'C:\Users\eliot\EPFL\TP4_ECAL\Code\ecal_reco\utils')
sys.path.insert(1, r'C:\Users\eliot\EPFL\TP4_ECAL\Code\ecal_reco\tracking')
from track3D import Track3D
from hit import Hit
from data_loading import *

# %%
file_path = 'C:\\Users\\eliot\\EPFL\\TP4_ECAL\\run_000005\\data_0000.root'
df_hits = load_dataset(file_path)
og_len = len(df_hits)
df_hits.query('n_hits > 6', inplace=True)
df_hits.query('n_hits < 50', inplace=True)
new_len = len(df_hits)
print('selected {:.2f}% of all events'.format(new_len/og_len * 100))

import matplotlib.pyplot as plt

n_bins=30


plt.figure()
plt.hist(df_hits['n_hits'],n_bins)
plt.xlabel("Number of hits", fontsize=16) 
plt.ylabel("Number of events", fontsize=16)
# Out:
# selected 51.48% of all events
# Text(0, 0.5, 'Number of events')

# %%
file_path2 = 'C:\\Users\\eliot\\EPFL\\TP4_ECAL\\run_000006\\data_0000.root'
df_hits2 = load_dataset(file_path2)
og_len2 = len(df_hits2)
df_hits2.query('n_hits > 6', inplace=True)
df_hits2.query('n_hits < 50', inplace=True)
new_len2 = len(df_hits2)
print('selected {:.2f}% of all events'.format(new_len2/og_len2 * 100))

import matplotlib.pyplot as plt

n_bins=30

plt.figure()
plt.hist(df_hits2['n_hits'],n_bins)
plt.xlabel("Number of hits", fontsize=16) 
plt.ylabel("Number of events", fontsize=16)
# Out:
# selected 74.85% of all events
# Text(0, 0.5, 'Number of events')

# %%
file_path3 = 'C:\\Users\\eliot\\EPFL\\TP4_ECAL\\run_000007\\data_0000.root'
df_hits3 = load_dataset(file_path3)
og_len3 = len(df_hits3)
df_hits3.query('n_hits > 6', inplace=True)
df_hits3.query('n_hits < 50', inplace=True)
new_len3 = len(df_hits3)
print('selected {:.2f}% of all events'.format(new_len3/og_len3 * 100))

import matplotlib.pyplot as plt

n_bins=30

plt.figure()
plt.hist(df_hits3['n_hits'],n_bins)
plt.xlabel("Number of hits", fontsize=16) 
plt.ylabel("Number of events", fontsize=16)
# Out:
# selected 74.62% of all events
# Text(0, 0.5, 'Number of events')

# %%
file_path4 = 'C:\\Users\\eliot\\EPFL\\TP4_ECAL\\run_000008\\data_0000.root'
df_hits4 = load_dataset(file_path4)
og_len4 = len(df_hits4)
df_hits4.query('n_hits > 6', inplace=True)
df_hits4.query('n_hits < 50', inplace=True)
new_len4 = len(df_hits4)
print('selected {:.2f}% of all events'.format(new_len4/og_len4 * 100))

plt.figure()
plt.hist(df_hits4['n_hits'],n_bins)
plt.xlabel("Number of hits", fontsize=16) 
plt.ylabel("Number of events", fontsize=16)
# Out:
# selected 74.58% of all events
# Text(0, 0.5, 'Number of events')
