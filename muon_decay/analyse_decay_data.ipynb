# %%
import sys
sys.path.insert(1, r'C:\Users\eliot\EPFL\TP4_ECAL\Code\ecal_reco\utils')
sys.path.insert(1, r'C:\Users\eliot\EPFL\TP4_ECAL\Code\ecal_reco\tracking')
import pandas as pd
import matplotlib.pyplot as plt
import os
from hit import Hit
raw_data_directory = 'C:\\Users\\eliot\\EPFL\\TP4_ECAL\\raw_data\\' #path to the ecal data
current_directory = os.getcwd()
data_storage = current_directory+"\\extracted_data\\"
run = []

# %%
# Create a list of all the values (energies) of the hits made by electrons
import functools
import operator
import fnmatch

if len(run) == 0:
    runs = fnmatch.filter(os.listdir(raw_data_directory), '*')

values = []
for run in runs:
    decay_data = pd.read_pickle(data_storage+"pickle_decay_data_"+run)
    hits_electron = decay_data['hits_electron']
    hits_electron = functools.reduce(operator.iconcat, hits_electron, [])
    for hit in hits_electron:
        values.append(hit.value)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\eliot\EPFL\TP4_ECAL\Code\ecal_reco\muon_decay\analyse_decay_data.ipynb Cell 2 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/eliot/EPFL/TP4_ECAL/Code/ecal_reco/muon_decay/analyse_decay_data.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> values = []
#      <a href='vscode-notebook-cell:/c%3A/Users/eliot/EPFL/TP4_ECAL/Code/ecal_reco/muon_decay/analyse_decay_data.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> for run in runs:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/eliot/EPFL/TP4_ECAL/Code/ecal_reco/muon_decay/analyse_decay_data.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a>     decay_data = pd.read_pickle(data_storage+"pickle_decay_data_"+run)
#      <a href='vscode-notebook-cell:/c%3A/Users/eliot/EPFL/TP4_ECAL/Code/ecal_reco/muon_decay/analyse_decay_data.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a>     hits_electron = decay_data['hits_electron']
#      <a href='vscode-notebook-cell:/c%3A/Users/eliot/EPFL/TP4_ECAL/Code/ecal_reco/muon_decay/analyse_decay_data.ipynb#W1sZmlsZQ%3D%3D?line=12'>13</a>     hits_electron = functools.reduce(operator.iconcat, hits_electron, [])
#
# File c:\Users\eliot\mambaforge\envs\ecal-env\Lib\site-packages\pandas\io\pickle.py:189, in read_pickle(filepath_or_buffer, compression, storage_options)
#     125 """
#     126 Load pickled pandas object (or any object) from file.
#     127
#    (...)
#     186 4    4    9
#     187 """
#     188 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 189 with get_handle(
#     190     filepath_or_buffer,
#     191     "rb",
#     192     compression=compression,
#     193     is_text=False,
#     194     storage_options=storage_options,
#     195 ) as handles:
#     196     # 1) try standard library Pickle
#     197     # 2) try pickle_compat (older pandas version) to handle subclass changes
#     198     # 3) try pickle_compat with latin-1 encoding upon a UnicodeDecodeError
#     200     try:
#     201         # TypeError for Cython complaints about object.__new__ vs Tick.__new__
#     202         try:
#
# File c:\Users\eliot\mambaforge\envs\ecal-env\Lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:\\Users\\eliot\\EPFL\\TP4_ECAL\\Code\\ecal_reco\\muon_decay\\extracted_data\\pickle_decay_data_run_000001'

# %%
# Histogram of values of electron hits
plt.hist(values,40,density=True)
plt.xlabel("value")
plt.grid(True)
plt.show()
